# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading the datasets

# %%
income_df = pd.read_csv('income_df_cleaned.csv')
medical_centers_df = pd.read_csv('medical_centers_df_cleaned.csv')
population_df = pd.read_csv('population_df_cleaned.csv')

# %% [markdown]
# # Merging the datasets on the 'neighborhood_name' and 'district_name' columns
#
# I will discart the year column for the analysis.

# %%
# Dropping the 'year' column from all dataframes, if it exists
income_df.drop(columns='year', errors='ignore', inplace=True)
medical_centers_df.drop(columns='year', errors='ignore', inplace=True)
population_df.drop(columns='year', errors='ignore', inplace=True)

# %% [markdown]
# #### Check if the values of the neighborhood_name column match

# %%
# Get unique values from the neighborhood_name column of each DataFrame
unique_neighborhood_income = set(income_df['neighborhood_name'].unique())
unique_neighborhood_medical_centers = set(medical_centers_df['neighborhood_name'].unique())
unique_neighborhood_population = set(population_df['neighborhood_name'].unique())

# Find the differences between the sets of unique values
differences_income_medical_centers = unique_neighborhood_income.symmetric_difference(unique_neighborhood_medical_centers)
differences_income_population = unique_neighborhood_income.symmetric_difference(unique_neighborhood_population)

# Print the found differences
if len(differences_income_medical_centers) > 0:
    print("Differences between 'neighborhood_name' in income and medical_centers:")
    print(differences_income_medical_centers)

if len(differences_income_population) > 0:
    print("Differences between 'neighborhood_name' in income and population:")
    print(differences_income_population)
# Out:
# Differences between 'neighborhood_name' in income and medical_centers:
# {'Sants - Badal', 'Sant Gervasi - la Bonanova', 'Sant Gervasi- la Bonanova', 'Sants-Badal', 'Sant Gervasi- Galvany', 'Sant Gervasi - Galvany'}
# Differences between 'neighborhood_name' in income and population:
# {'Sants - Badal', 'Sant Gervasi - la Bonanova', 'Sant Gervasi- la Bonanova', 'Sants-Badal', 'Sant Gervasi- Galvany', 'Sant Gervasi - Galvany'}

# %% [markdown]
# #### Standardize the 'neighborhood_name' values across DataFrames

# %%
# Define a mapping of inconsistent names to standardized names
name_mapping = {
    'Sant Gervasi- la Bonanova': 'Sant Gervasi - la Bonanova',
    'Sants-Badal': 'Sants - Badal',
    'Sant Gervasi- Galvany': 'Sant Gervasi - Galvany',
}

# Apply the mapping to the 'neighborhood_name' column in each DataFrame
income_df['neighborhood_name'] = income_df['neighborhood_name'].replace(name_mapping)
medical_centers_df['neighborhood_name'] = medical_centers_df['neighborhood_name'].replace(name_mapping)
population_df['neighborhood_name'] = population_df['neighborhood_name'].replace(name_mapping)

# %%
# Check if the 'neighborhood_name' values match in all three DataFrames
matching_neighborhoods = set(income_df['neighborhood_name']).intersection(
    medical_centers_df['neighborhood_name'], population_df['neighborhood_name']
)

if len(matching_neighborhoods) == len(set(income_df['neighborhood_name'])):
    print("All 'neighborhood_name' values match in the three DataFrames.")
else:
    print("There are still differences in 'neighborhood_name' values.")
# Out:
# All 'neighborhood_name' values match in the three DataFrames.

# %% [markdown]
# #### Check if the values of the district_name column match

# %%
# Extract the 'district_name' column from each DataFrame and convert it to a set
income_districts = set(income_df['district_name'])
medical_centers_districts = set(medical_centers_df['district_name'])
population_districts = set(population_df['district_name'])

# Check if the 'district_name' sets are equal for all three DataFrames
if income_districts == medical_centers_districts == population_districts:
    print("The 'district_name' column matches between all three DataFrames.")
else:
    print("The 'district_name' column does not match between all three DataFrames.")
# Out:
# The 'district_name' column matches between all three DataFrames.

# %% [markdown]
# Now we can merge the DataFrames.

# %% [markdown]
# ## Merge DataFrames

# %%
# Merge the DataFrames on 'neighborhood_name' and 'district_name' columns
merged_df = income_df.merge(medical_centers_df, on=['neighborhood_name', 'district_name'], how='inner')
merged_df = merged_df.merge(population_df, on=['neighborhood_name', 'district_name'], how='inner')

# Now, merged_df contains the merged data based on both 'neighborhood_name' and 'district_name'

# %%
merged_df
# Out:
#                 neighborhood_name        district_name  median_income  \
# 0                   Baró de Viver          Sant Andreu        29438.5
# 1                        Can Baró       Horta-Guinardó        45922.0
# 2                     Can Peguera           Nou Barris        28117.0
# 3                       Canyelles           Nou Barris        43158.0
# 4                Ciutat Meridiana           Nou Barris        29393.5
# ..                            ...                  ...            ...
# 68  la Vila Olímpica del Poblenou           Sant Martí        83317.0
# 69              la Vila de Gràcia               Gràcia        50733.0
# 70                      les Corts            Les Corts        65816.0
# 71                   les Roquetes           Nou Barris        31584.0
# 72                les Tres Torres  Sarrià-Sant Gervasi       131719.0
#
#                                        medical_center  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 68            Centre d'Atenció Primària Vila Olímpica
# 69  Clínica Sanza, Centre d'Atenció Primària  Vila...
# 70  Clínica Institut Marquès, Hospital de Barcelon...
# 71                 Centre d'Atenció Primària Roquetes
# 72  Clínica Oftalvist, Clinica del Son Estivill, I...
#
#                                         type  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ..                                       ...
# 68                                       CAP
# 69                         Other, CAP, Other
# 70            Other, Hospital, Hospital, CAP
# 71                                       CAP
# 72  Other, Other, Other, Other, Other, Other
#
#                                                 admin  population  \
# 0                                                None        2645
# 1                                                None        9233
# 2                                                None        2204
# 3                                                None        6797
# 4                                                None       11026
# ..                                                ...         ...
# 68                                             Public        9240
# 69                           Private, Public, Private       49492
# 70                  Private, Private, Private, Public       45422
# 71                                             Public       16373
# 72  Private, Private, Private, Private, Private, P...       16228
#
#     residential_area_ha  net_density_hab_ha
# 0                   3.9                 673
# 1                  14.3                 645
# 2                   6.1                 359
# 3                  11.0                 620
# 4                  15.1                 729
# ..                  ...                 ...
# 68                 24.3                 380
# 69                 84.0                 589
# 70                 64.7                 702
# 71                 18.2                 897
# 72                 42.5                 382
#
# [73 rows x 9 columns]

# %% [markdown]
# # Check on the main features

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73 entries, 0 to 72
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   neighborhood_name    73 non-null     object
#  1   district_name        73 non-null     object
#  2   median_income        73 non-null     float64
#  3   medical_center       73 non-null     object
#  4   type                 73 non-null     object
#  5   admin                73 non-null     object
#  6   population           73 non-null     int64
#  7   residential_area_ha  73 non-null     float64
#  8   net_density_hab_ha   73 non-null     int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 5.7+ KB

# %% [markdown]
# We don't have null values and data types are correct.

# %%
# To check for duplicates in all the rows:
duplicates = merged_df[merged_df.duplicated()]
duplicates.count()
# Out:
# neighborhood_name      0
# district_name          0
# median_income          0
# medical_center         0
# type                   0
# admin                  0
# population             0
# residential_area_ha    0
# net_density_hab_ha     0
# dtype: int64

# %% [markdown]
# We don't have duplicates.

# %%
# For loop to iterate through all columns 
# View unique values and count values
for column in merged_df.columns:
    unique_values = merged_df[column].unique()
    value_counts = merged_df[column].value_counts()
    print(f"Column: {column}")
    print("Unique Values:")
    print(unique_values)
    print("Value Counts:")
    print(value_counts)
# Out:
# Column: neighborhood_name
# Unique Values:
# ['Baró de Viver' 'Can Baró' 'Can Peguera' 'Canyelles' 'Ciutat Meridiana'
#  'Diagonal Mar i el Front Marítim del Poblenou' 'Horta' 'Hostafrancs'
#  'Montbau' 'Navas' 'Pedralbes' 'Porta' 'Provençals del Poblenou'
#  'Sant Andreu' 'Sant Antoni' 'Sant Genís dels Agudells'
#  'Sant Gervasi - Galvany' 'Sant Gervasi - la Bonanova'
#  'Sant Martí de Provençals' 'Sant Pere, Santa Caterina i la Ribera'
#  'Sants' 'Sants - Badal' 'Sarrià' 'Torre Baró' 'Vallbona'
#  'Vallcarca i els Penitents' 'Vallvidrera, el Tibidabo i les Planes'
#  'Verdun' 'Vilapicina i la Torre Llobeta' 'el Baix Guinardó'
#  'el Barri Gòtic' 'el Besòs i el Maresme' 'el Bon Pastor'
#  "el Camp d'en Grassot i Gràcia Nova" "el Camp de l'Arpa del Clot"
#  'el Carmel' 'el Clot' 'el Coll' 'el Congrés i els Indians'
#  'el Fort Pienc' 'el Guinardó' 'el Parc i la Llacuna del Poblenou'
#  'el Poble Sec' 'el Poblenou' 'el Putxet i el Farró' 'el Raval'
#  'el Turó de la Peira' "l'Antiga Esquerra de l'Eixample" 'la Barceloneta'
#  'la Bordeta' 'la Clota' "la Dreta de l'Eixample" "la Font d'en Fargues"
#  'la Font de la Guatlla' 'la Guineueta' 'la Marina de Port'
#  'la Marina del Prat Vermell' 'la Maternitat i Sant Ramon'
#  "la Nova Esquerra de l'Eixample" 'la Prosperitat' 'la Sagrada Família'
#  'la Sagrera' 'la Salut' 'la Teixonera' 'la Trinitat Nova'
#  'la Trinitat Vella' "la Vall d'Hebron" 'la Verneda i la Pau'
#  'la Vila Olímpica del Poblenou' 'la Vila de Gràcia' 'les Corts'
#  'les Roquetes' 'les Tres Torres']
# Value Counts:
# Baró de Viver             1
# el Coll                   1
# la Font de la Guatlla     1
# la Font d'en Fargues      1
# la Dreta de l'Eixample    1
#                          ..
# Vallbona                  1
# Torre Baró                1
# Sarrià                    1
# Sants - Badal             1
# les Tres Torres           1
# Name: neighborhood_name, Length: 73, dtype: int64
# Column: district_name
# Unique Values:
# ['Sant Andreu' 'Horta-Guinardó' 'Nou Barris' 'Sant Martí' 'Sants-Montjuïc'
#  'Les Corts' 'Eixample' 'Sarrià-Sant Gervasi' 'Ciutat Vella' 'Gràcia']
# Value Counts:
# Nou Barris             13
# Horta-Guinardó         11
# Sant Martí             10
# Sants-Montjuïc          8
# Sant Andreu             7
# Eixample                6
# Sarrià-Sant Gervasi     6
# Gràcia                  5
# Ciutat Vella            4
# Les Corts               3
# Name: district_name, dtype: int64
# Column: median_income
# Unique Values:
# [ 29438.5  45922.   28117.   43158.   29393.5  60322.   48919.   45256.5
#   44081.5  48680.  131719.   38889.   45927.5  49842.   51740.5  41460.
#   96493.  109582.5  40957.   38023.   48634.   44526.5  93898.5  32808.
# Centre d'Atenció Primària, Centre d'Atenció Primària, Hospital de Dia                                                                                                                                                                                                                                                            1
# Centre d'Atenció Primària Sardenya                                                                                                                                                                                                                                                                                               1
# Centre d'Atenció Primària Gòtic                                                                                                                                                                                                                                                                                                  1
# Centre d'Atenció Primària Besòs, Hospital de Dia                                                                                                                                                                                                                                                                                 1
# Centre d'Atenció Primària Bon Pastor                                                                                                                                                                                                                                                                                             1
# Clínica Nostra Senyora del Remei, Centre d'Atenció Primària Pare Claret                                                                                                                                                                                                                                                          1
# Hospital de Dia Còrsega, Centre d'Atenció Primària Passeig Maragall                                                                                                                                                                                                                                                              1
# Clínica Oftalvist, Clinica del Son Estivill, Instituto Oftalmológico Tres Torres, Centre Planificació Familiar, Clínica Mi Tres Torres, Clínica Corachan                                                                                                                                                                         1
# Name: medical_center, dtype: int64
# Column: type
# Unique Values:
# ['None' 'CAP' 'Hospital, CUAP, Other, Other'
#  'Hospital, Hospital, Other, CAP' 'Other' 'CUAP, Other, CAP, Other, CAP'
#  'CAP, CAP'
#  'Other, CAP, Hospital, Hospital, Other, Other, Other, CUAP, Hospital'
#  'Other, Other, Other, Other, Other, Other' 'Hospital, CAP, Other, CAP'
#  'Hospital, Hospital, CAP, Other, Other, Other'
#  'CAP, Hospital, Other, Hospital, Hospital' 'Hospital'
#  'CAP, CAP, Hospital' 'CAP, Hospital' 'Other, CAP' 'Hospital, CAP'
#  'CAP, CAP, Other' 'Hospital, Other, CAP' 'Hospital, Other'
#  'CAP, CAP, CUAP' 'CAP, Hospital, Other, Other' 'Other, Hospital, CAP'
#  'Hospital, CAP, Other' 'Hospital, CAP, Other, Other, CAP'
#  'Other, Hospital, CAP, Hospital' 'CAP, Other, CUAP, Other, Hospital'
#  'CAP, Other, Other'
#  'Hospital, Hospital, CAP, CAP, Hospital, Hospital, CAP'
#  'Other, CAP, Other' 'Other, Hospital, Hospital, CAP']
# Value Counts:
# None                                                                   20
# CAP                                                                    18
# CAP, CAP                                                                5
# CAP, Hospital                                                           2
# Other, Other, Other, Other, Other, Other                                2
# CAP, Other, CUAP, Other, Hospital                                       1
# CAP, Other, Other                                                       1
# Other, Hospital, CAP, Hospital                                          1
# Hospital, Other, CAP                                                    1
# Hospital, CAP, Other, Other, CAP                                        1
# Hospital, CAP, Other                                                    1
# Other, Hospital, CAP                                                    1
# CAP, Hospital, Other, Other                                             1
# CAP, CAP, CUAP                                                          1
# Hospital, Hospital, CAP, CAP, Hospital, Hospital, CAP                   1
# Other, CAP, Other                                                       1
# Hospital, Other                                                         1
# Other, CAP                                                              1
# CAP, CAP, Other                                                         1
# Hospital, CAP                                                           1
# CAP, CAP, Hospital                                                      1
# Hospital                                                                1
# CAP, Hospital, Other, Hospital, Hospital                                1
# Hospital, Hospital, CAP, Other, Other, Other                            1
# Hospital, CAP, Other, CAP                                               1
# Other, CAP, Hospital, Hospital, Other, Other, Other, CUAP, Hospital     1
# CUAP, Other, CAP, Other, CAP                                            1
# Other                                                                   1
# Hospital, Hospital, Other, CAP                                          1
# Hospital, CUAP, Other, Other                                            1
# Other, Hospital, Hospital, CAP                                          1
# Name: type, dtype: int64
# Column: admin
# Unique Values:
# ['None' 'Public' 'Private, Public, Private, Private'
#  'Private, Public, Private, Public' 'Private'
#  'Public, Private, Public, Private, Public' 'Public, Public'
#  'Private, Public, Private, Private, Private, Private, Private, Public, Private'
#  'Private, Private, Private, Private, Private, Private'
#  'Private, Private, Public, Private, Private, Private'
#  'Public, Private, Private, Private, Private' 'Public, Public, Private'
#  'Public, Private' 'Private, Public' 'Private, Private, Public'
#  'Private, Private' 'Public, Public, Public'
#  'Public, Public, Private, Private' 'Private, Public, Public'
#  'Private, Public, Private' 'Private, Public, Private, Private, Public'
#  'Private, Private, Public, Private'
#  'Public, Private, Public, Private, Private' 'Public, Private, Private'
#  'Private, Private, Public, Public, Public, Private, Public'
#  'Private, Private, Private, Public']
# Value Counts:
# None                                                                             20
# Public                                                                           18
# Public, Public                                                                    5
# Private, Private, Private, Private, Private, Private                              2
# Private, Public, Private                                                          2
# Public, Private                                                                   2
# Public, Public, Private                                                           2
# Private, Public                                                                   2
# Private                                                                           2
# Private, Public, Private, Public                                                  2
# Private, Public, Private, Private, Private, Private, Private, Public, Private     1
# Private, Public, Public                                                           1
# Private, Private, Public, Public, Public, Private, Public                         1
# Public, Private, Private                                                          1
# Public, Private, Public, Private, Private                                         1
# Private, Private, Public, Private                                                 1
# Private, Public, Private, Private, Public                                         1
# Private, Public, Private, Private                                                 1
# Public, Public, Private, Private                                                  1
# Private, Private, Public, Private, Private, Private                               1
# Public, Public, Public                                                            1
# Private, Private                                                                  1
# Private, Private, Public                                                          1
# Public, Private, Public, Private, Public                                          1
# Public, Private, Private, Private, Private                                        1
# Private, Private, Private, Public                                                 1
# Name: admin, dtype: int64
# Column: population
# Unique Values:
# [ 2645  9233  2204  6797 11026 13323 27707 15842  5071 22091 11581 27418
#  20949 57954 38053  7249 46816 25659 26032 22131 43082 24576 24405  2890
#   1384 16142  4697 12727 25674 25601 21827 25657 13582 34932 38360 32444
#  26520  7590 14420 31262 36939 15603 39400 33976 29629 47228 16025 41990
#  14643 19292   689 44675  9458 10084 15189 30741  1350 23574 57054 26669
#  51319 29351 13282 11926  7507 10364  5882 28585  9240 49492 45422 16373
#  16228]
# Value Counts:
# 2645     1
# 7590     1
# 10084    1
# 9458     1
# 44675    1
#         ..
# 1384     1
# 2890     1
# 24405    1
# 24576    1
# 16228    1
# Name: population, Length: 73, dtype: int64
# Column: residential_area_ha
# Unique Values:
# [  3.9  14.3   6.1  11.   15.1  24.   63.2  22.1  11.4  22.4  81.7  35.7
#   15.3  76.5  41.3  16.9  95.4  82.1  23.4  32.4  59.4  25.1  21.2   6.8
#   48.2 242.   14.2  29.3  23.7  34.1  28.1  17.8  38.5  42.9  39.4  12.4
#   19.1  33.6  52.   22.3  38.1  45.   53.1  49.6  13.3  66.9  13.5  20.8
#  113.9  38.8  11.5  22.   38.9  35.5  31.8  65.2  27.1  51.   19.5  12.6
#   12.7   7.2  40.   24.3  84.   64.7  18.2  42.5]
# Value Counts:
# 23.4    2
# 6.1     2
# 95.4    2
# 38.1    2
# 16.9    2
#        ..
# 28.1    1
# 17.8    1
# 38.5    1
# 42.9    1
# 42.5    1
# Name: residential_area_ha, Length: 68, dtype: int64
# Column: net_density_hab_ha
# Unique Values:
# [ 673  645  359  620  729  556  439  717  447  984  142  768 1368  758
#   921  430  491  313 1111  683  726  980  256  136  204  335   19  894
#   875 1079  639  913  763  907  822 1131  611  753  930  710  699 1033
#   755  558  952 1204  627 1081  928  114  392  244  873  689  789   38
#   741  876  985 1007  770  680  707  598  817  813  714  380  589  702
#   897  382]
# Value Counts:
# 894    2
# 753    1
# 873    1
# 244    1
# 392    1
#       ..
# 136    1
# 256    1
# 980    1
# 726    1
# 382    1
# Name: net_density_hab_ha, Length: 72, dtype: int64

# %% [markdown]
# In Barcelona, there are 10 districts, and when checking the 'district_name' column, we see that everything is correct because there are 10 unique values that correctly represent the names of the 10 districts.
#
# Also in the 'neighborhood_name' column, we observe that the 73 neighborhoods of Barcelona are listed.

# %% [markdown]
# ### I will change the median_income type from float to int.

# %%
merged_df['median_income'] = merged_df['median_income'].astype(int)

# %%
merged_df['median_income'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# # Split into Categorical and Numerical

# %%
# Select categorical columns (object and category data types)
categorical_df = merged_df.select_dtypes(include=['object', 'category'])

# Select numerical columns (int and float data types)
numerical_df = merged_df.select_dtypes(include=['int', 'float'])

# %%
numerical_df
# Out:
#     median_income  population  residential_area_ha  net_density_hab_ha
# 0           29438        2645                  3.9                 673
# 1           45922        9233                 14.3                 645
# 2           28117        2204                  6.1                 359
# 3           43158        6797                 11.0                 620
# 4           29393       11026                 15.1                 729
# ..            ...         ...                  ...                 ...
# 68          83317        9240                 24.3                 380
# 69          50733       49492                 84.0                 589
# 70          65816       45422                 64.7                 702
# 71          31584       16373                 18.2                 897
# 72         131719       16228                 42.5                 382
#
# [73 rows x 4 columns]

# %%
categorical_df
# Out:
#                 neighborhood_name        district_name  \
# 0                   Baró de Viver          Sant Andreu
# 1                        Can Baró       Horta-Guinardó
# 2                     Can Peguera           Nou Barris
# 3                       Canyelles           Nou Barris
# 4                Ciutat Meridiana           Nou Barris
# ..                            ...                  ...
# 68  la Vila Olímpica del Poblenou           Sant Martí
# 69              la Vila de Gràcia               Gràcia
# 70                      les Corts            Les Corts
# 71                   les Roquetes           Nou Barris
# 72                les Tres Torres  Sarrià-Sant Gervasi
#
#                                        medical_center  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 68            Centre d'Atenció Primària Vila Olímpica
# 69  Clínica Sanza, Centre d'Atenció Primària  Vila...
# 70  Clínica Institut Marquès, Hospital de Barcelon...
# 71                 Centre d'Atenció Primària Roquetes
# 72  Clínica Oftalvist, Clinica del Son Estivill, I...
#
#                                         type  \
# 0                                       None
# 1                                       None
# 2                                       None
# 3                                       None
# 4                                       None
# ..                                       ...
# 68                                       CAP
# 69                         Other, CAP, Other
# 70            Other, Hospital, Hospital, CAP
# 71                                       CAP
# 72  Other, Other, Other, Other, Other, Other
#
#                                                 admin
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# ..                                                ...
# 68                                             Public
# 69                           Private, Public, Private
# 70                  Private, Private, Private, Public
# 71                                             Public
# 72  Private, Private, Private, Private, Private, P...
#
# [73 rows x 5 columns]

# %% [markdown]
# # Saving

# %%
# Reset the index of merged_df
merged_df = merged_df.reset_index(drop=True)

# Save the DataFrame to a CSV file
merged_df.to_csv('merged_data.csv', index=False)
